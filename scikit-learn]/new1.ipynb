# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes

# %%
X , y = load_diabetes(return_X_y=True)

# %%
pipe = Pipeline([
    ('scalar',StandardScaler()),
    ('model',KNeighborsRegressor()),
])

# %%
pipe.fit(X,y)
# Out:
# Pipeline(steps=[('scalar', StandardScaler()), ('model', KNeighborsRegressor())])

# %%
pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('scalar', StandardScaler()), ('model', KNeighborsRegressor())],
#  'transform_input': None,
#  'verbose': False,
#  'scalar': StandardScaler(),
#  'model': KNeighborsRegressor(),
#  'scalar__copy': True,
#  'scalar__with_mean': True,
#  'scalar__with_std': True,
#  'model__algorithm': 'auto',
#  'model__leaf_size': 30,
#  'model__metric': 'minkowski',
#  'model__metric_params': None,
#  'model__n_jobs': None,
#  'model__n_neighbors': 5,
#  'model__p': 2,
#  'model__weights': 'uniform'}

# %%
model = GridSearchCV(estimator=pipe, param_grid={'model__n_neighbors': range(1,10)},cv=3)

# %%
model.fit(X,y)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('scalar', StandardScaler()),
#                                        ('model', KNeighborsRegressor())]),
#              param_grid={'model__n_neighbors': range(1, 10)})

# %%
model.predict(X)
# Out:
# array([200.        ,  97.55555556, 144.33333333, 200.22222222,
#        100.66666667, 126.55555556,  78.22222222, 150.        ,
#        130.        , 195.88888889, 128.55555556, 146.11111111,
#        112.11111111, 144.88888889,  96.77777778, 190.66666667,
#        179.77777778, 183.33333333, 132.44444444, 105.55555556,
#        103.        ,  73.88888889, 129.66666667, 252.22222222,
#        171.        , 118.33333333, 115.88888889, 135.44444444,
#        116.        , 189.55555556, 136.33333333,  81.44444444,
#        275.11111111,  97.88888889,  79.11111111, 115.11111111,
#        162.66666667, 149.44444444, 205.44444444,  80.77777778,
#        165.11111111, 111.        , 122.44444444,  90.55555556,
#        235.88888889,  86.55555556, 161.11111111, 140.44444444,
#         85.22222222, 147.55555556, 121.44444444, 145.66666667,
#        132.88888889, 124.88888889, 118.33333333,  83.22222222,
#        159.44444444,  90.        , 114.55555556, 163.        ,
#        103.66666667, 121.66666667,  60.33333333, 127.44444444,
#        116.55555556, 150.        , 132.88888889, 102.44444444,
#         98.        , 109.33333333,  89.        , 207.11111111,
#        159.44444444, 129.55555556, 162.66666667,  85.11111111,
#        162.66666667,  96.88888889, 161.44444444, 141.44444444,
#        142.11111111, 118.22222222,  76.55555556, 137.44444444,
#         71.66666667, 138.66666667,  81.22222222, 126.44444444,
#         72.88888889,  91.22222222, 101.33333333, 143.22222222,
#        194.11111111,  89.66666667,  95.33333333, 109.22222222,
#        207.44444444, 201.55555556,  92.66666667, 145.11111111,
#        155.11111111, 111.44444444, 140.22222222, 171.44444444,
#        120.77777778,  97.11111111, 115.11111111, 139.77777778,
#        187.22222222, 179.        ,  76.77777778, 107.66666667,
#        161.66666667, 185.44444444, 251.44444444, 181.44444444,
#        218.33333333, 216.66666667, 163.66666667, 134.44444444,
#        124.66666667, 200.44444444, 230.66666667, 191.55555556,
#        159.33333333, 160.        ,  90.66666667,  78.66666667,
#        104.88888889, 226.88888889, 259.44444444, 111.66666667,
#        125.        ,  85.        , 135.        , 199.66666667,
#         89.22222222, 249.88888889, 276.        , 250.55555556,
#        153.66666667, 244.66666667, 206.66666667, 114.33333333,
#        195.88888889, 199.88888889, 166.22222222, 208.55555556,
#        102.33333333, 123.11111111, 205.77777778, 112.55555556,
#        200.22222222, 125.55555556, 173.55555556, 191.88888889,
#        143.33333333, 114.22222222, 118.88888889, 223.88888889,
#         94.44444444, 231.44444444, 143.11111111, 237.11111111,
#        112.77777778,  82.11111111,  85.        , 227.33333333,
#        245.        , 211.22222222,  81.77777778,  88.44444444,
#        260.44444444,  88.77777778, 129.88888889, 116.88888889,
#        223.33333333, 193.33333333, 101.11111111, 179.55555556,
#        139.88888889,  90.55555556, 182.11111111, 163.22222222,
